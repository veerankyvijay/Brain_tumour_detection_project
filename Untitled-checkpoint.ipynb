# %%
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import numpy as np 
import pandas as pd
import os
directory_path = r"C:/Users/vijay/Desktop/brain_tumor_project"
for dirname, _,filenames in os.walk(directory_path):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# C:/Users/vijay/Desktop/brain_tumor_project\braintumor.h5
# C:/Users/vijay/Desktop/brain_tumor_project\gui.py
# C:/Users/vijay/Desktop/brain_tumor_project\model.json
# C:/Users/vijay/Desktop/brain_tumor_project\Untitled.ipynb
# C:/Users/vijay/Desktop/brain_tumor_project\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(1).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(10).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(100).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(11).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(12).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(13).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(14).jpg
# C:/Users/vijay/Desktop/brain_tumor_project\Testing\glioma_tumor\image(15).jpg
# ...

# %%
import keras
#from keras i have importing and using the model in deep learning  called sequential model so it is common in every model
#so we can use this model for CNN,ANN and RECURRENT NEURAL NETWORK(RNN)
from keras.models import Sequential
# now we import some layers which are there in this neural network
#between import layer and output layer we have some hidden layers in this(NN)
from keras.layers import Conv2D,Flatten,Dense ,MaxPooling2D,Dropout
#so for getting the  accuracy i have importing the another library from sklearn
from sklearn.metrics import accuracy_score

# %%
#In my dataset there four types of images for analysing that we need ipywidgets
#ipywidgets is useful for number of tasks, particularly for model development, exploration, and visualization
import ipywidgets as  widgets
#io module provides the tools for handling various types of input and output operations, such as reading from and writing to files, in-memory streams, and more
import io
#powerful library used for opening, manipulating, and saving image files
from PIL import Image
#Python library used to create progress bars for loops
# monitor the progress of training processes, data loading, and other lengthy operations
import tqdm
from sklearn.model_selection import train_test_split
#a popular open-source computer vision and image processing library
import cv2
#fro shuffle the 4 types of images we use utils and import shuffles
from sklearn.utils import shuffle
import tensorflow as tf

# %% [markdown]
# SETTING FOLDER PATHS

# %%
X_train=[]
Y_train=[]
image_size=150
labels=['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath=os.path.join("C:/Users/vijay/Desktop/brain_tumor_project/Training",i)
    for j in os.listdir(folderPath):#listing all the data to the list by listdir
   #now reading the images
        img=cv2.imread(os.path.join(folderPath,j))
        img=cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
for i in labels:
    folderPath=os.path.join("C:/Users/vijay/Desktop/brain_tumor_project/Testing",i)
    for j in os.listdir(folderPath):#listing all the data to the list by listdir
   #now reading the images
        img=cv2.imread(os.path.join(folderPath,j))
        img=cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train=np.array(X_train)
Y_train=np.array(Y_train)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %% [markdown]
# Train test split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
# Check y_train and y_test to ensure they contain labels
print(f"y_train sample: {y_train[:5]}")
print(f"y_test sample: {y_test[:5]}")

# Convert labels to indices and then to categorical
y_train_new = [labels.index(i) for i in y_train]
y_train = tf.keras.utils.to_categorical(y_train_new)

y_test_new = [labels.index(i) for i in y_test]
y_test = tf.keras.utils.to_categorical(y_test_new)
# Out:
# y_train sample: ['glioma_tumor' 'meningioma_tumor' 'meningioma_tumor' 'glioma_tumor'
#  'pituitary_tumor']
# y_test sample: ['pituitary_tumor' 'no_tumor' 'glioma_tumor' 'meningioma_tumor'
#  'pituitary_tumor']

# %% [markdown]
# convolutional neural network (CNN)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4,activation='softmax'))
# Out:
# C:\Users\vijay\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#here i will getting the created model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 146, 146, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 73, 73, 64)          │               0 │
# ...

# %% [raw]
# from the above summary my model is looking pretty good now iam going to the next step for training part before going to train the model I have to compile the model which means setting up all the models inside 1

# %% [markdown]
# compiling the model

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
#here my model is compiled and now iam going for training session

# %%
history=model.fit(X_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.2809 - loss: 3.7769 - val_accuracy: 0.2789 - val_loss: 1.3647
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.3304 - loss: 1.3417 - val_accuracy: 0.4456 - val_loss: 1.2142
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5104 - loss: 1.0867 - val_accuracy: 0.5782 - val_loss: 0.9767
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6070 - loss: 0.9116 - val_accuracy: 0.5612 - val_loss: 0.9675
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.6682 - loss: 0.7707 - val_accuracy: 0.6803 - val_loss: 0.7764
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.7340 - loss: 0.6584 - val_accuracy: 0.6395 - val_loss: 0.7505
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7810 - loss: 0.5463 - val_accuracy: 0.7619 - val_loss: 0.6028
# Epoch 8/20
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.8401 - loss: 0.4991
# [0.4931671917438507, 0.8501529097557068]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
model.save('braintumor.h5')
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
epochs=range(len(acc))
fig=plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label="validation_Accuracy")
plt.legend(loc='upper left')
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(len(acc))
fig=plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label='Training loss')
plt.plot(epochs,val_loss,'b',label="validation_loss")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# prediction of the model

# %%
img=cv2.imread('C:/Users/vijay/Desktop/brain_tumor_project/Testing/meningioma_tumor/images.jpg')
img=cv2.resize(img,(150,150))
img_array=np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array=img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img('C:/Users/vijay/Desktop/brain_tumor_project/Testing/meningioma_tumor/images.jpg')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a=model.predict(img_array)
indices=a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1

# %%
model_json = model.to_json()  # Save the model architecture to a variable
with open("model.json", "w") as json_file:
    json_file.write(model_json)  # Write the model architecture to the file
